# %% [markdown]
# # Brief Introduction
#
# ### Here I implemented the decision tree by myeslf and then I trained the dataset with both, my model and the decision tree from sklearn
#
# ![Banner-detect-breast-cancer-with-Ai.webp](attachment:3af15d14-079f-4620-a5a7-82a28ca2be74.webp)

# %%
# Libraries

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.metrics import accuracy_score, classification_report
from DecisionTree import DecisionTree

# %%
data = datasets.load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1234)

# %%
clf = DecisionTree(max_depth = 10)
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)

# %%
def accuracy(y_test, y_pred):
    return np.sum(y_test == y_pred) / len(y_test)

# %%
acc = accuracy(y_test, predictions)
print(acc)
# Out:
# 0.9210526315789473

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90        45
#            1       0.92      0.96      0.94        69
#
#     accuracy                           0.92       114
#    macro avg       0.92      0.91      0.92       114
# weighted avg       0.92      0.92      0.92       114
